# %% [markdown]
# #### Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool
#
# ### Adv:
# 1) Works very well with structured Data

# %%
import pandas as pd
df = pd.read_csv('customers-100.csv')

# %%
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df = pd.read_csv('customers-100.csv', header = None)   # Assigns indexes to both rows and columns
df
# Out:
#         0                1           2          3   \
# 0    Index      Customer Id  First Name  Last Name
# 1        1  DD37Cf93aecA6Dc      Sheryl     Baxter
# 2        2  1Ef7b82A4CAAD10     Preston     Lozano
# 3        3  6F94879bDAfE5a6         Roy      Berry
# 4        4  5Cef8BFA16c5e3c       Linda      Olsen
# ..     ...              ...         ...        ...
# 96      96  cb8E23e48d22Eae        Karl      Greer
# 97      97  CeD220bdAaCfaDf        Lynn   Atkinson
# 98      98  28CDbC0dFe4b1Db        Fred     Guerra
# 99      99  c23d1D9EE8DEB0A      Yvonne     Farmer
# 100    100  2354a0E336A91A1    Clarence     Haynes
#
#                                   4                  5                    6   \
# 0                            Company               City              Country
# 1                    Rasmussen Group       East Leonard                Chile
# 2                        Vega-Gentry  East Jimmychester             Djibouti
# ...

# %%
df = pd.read_csv('customers-100.csv', skiprows = 3)
df
# Out:
#       3  6F94879bDAfE5a6       Roy     Berry                    Murillo-Perry  \
# 0     4  5Cef8BFA16c5e3c     Linda     Olsen  Dominguez, Mcmillan and Donovan
# 1     5  053d585Ab6b3159    Joanna    Bender         Martin, Lang and Andrade
# 2     6  2d08FB17EE273F4     Aimee     Downs                     Steele Group
# 3     7  EA4d384DfDbBf77    Darren      Peck     Lester, Woodard and Mitchell
# 4     8  0e04AFde9f225dE     Brett    Mullen     Sanford, Davenport and Giles
# ..  ...              ...       ...       ...                              ...
# 92   96  cb8E23e48d22Eae      Karl     Greer                        Carey LLC
# 93   97  CeD220bdAaCfaDf      Lynn  Atkinson            Ware, Burns and Oneal
# 94   98  28CDbC0dFe4b1Db      Fred    Guerra                    Schmitt-Jones
# 95   99  c23d1D9EE8DEB0A    Yvonne    Farmer               Fitzgerald-Harrell
# 96  100  2354a0E336A91A1  Clarence    Haynes               Le, Nash and Cross
#
# ...

# %%
df = pd.read_csv('customers-100.csv', usecols = ['Index', 'Customer Id', 'First Name', 'Last Name',	'Company'])  # This will only display cols we have mentioned
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company
# 0                   Rasmussen Group
# 1                       Vega-Gentry
# 2                     Murillo-Perry
# 3   Dominguez, Mcmillan and Donovan
# 4          Martin, Lang and Andrade
# ..                              ...
# 95                        Carey LLC
# 96            Ware, Burns and Oneal
# 97                    Schmitt-Jones
# ...

# %% [markdown]
# #### Data Structure  >> Series and DataFrame
# ### Series is 1D in nature
# ### Data Frame is made of various series and is 2D in nature

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv('customers-100.csv')
df
# Out:
#     Index      Customer_Id First_Name Last_Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.Country
# Out:
# 0                          Chile
# 1                       Djibouti
# 2            Antigua and Barbuda
# 3             Dominican Republic
# 4     Slovakia (Slovak Republic)
#                  ...
# 95                        Guyana
# 96                     Sri Lanka
# 97               Solomon Islands
# 98                         Aruba
# 99                      Honduras
# Name: Country, Length: 100, dtype: object

# %%
df['First_Name']   # This is used when there is no underscore between two words
# Out:
# 0       Sheryl
# 1      Preston
# 2          Roy
# 3        Linda
# 4       Joanna
#         ...
# 95        Karl
# 96        Lynn
# 97        Fred
# 98      Yvonne
# 99    Clarence
# Name: First_Name, Length: 100, dtype: object

# %%
type(df['Customer_Id'])
# Out:
# pandas.core.series.Series

# %%
type(df)  # DF is made from one or more series( There are several series here like index, Customer_Id, First_Name, etc)
# Out:
# pandas.core.frame.DataFrame

# %%
l = [1,2,3]
s = pd.Series(l)  # Converts data into series
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s[2:4]
# Out:
# 2    3
# dtype: int64

# %%
s[1:]
# Out:
# 1    2
# 2    3
# dtype: int64

# %%
a = pd.Series([10,20,30,40,50], index = ["Aashish", "Karan", "Rishi", "Rahul", "Shobit"])
a
# Out:
# Aashish    10
# Karan      20
# Rishi      30
# Rahul      40
# Shobit     50
# dtype: int64

# %%
a.index
# Out:
# Index(['Aashish', 'Karan', 'Rishi', 'Rahul', 'Shobit'], dtype='object')

# %%
a.reset_index()
# Out:
#      index   0
# 0  Aashish  10
# 1    Karan  20
# 2    Rishi  30
# 3    Rahul  40
# 4   Shobit  50

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a.reset_index(drop = True)   # It means throw the old index instead of keeping it as a column and create a new one
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
pd.DataFrame(a)  # Converts
# Out:
#           0
# Aashish  10
# Karan    20
# Rishi    30
# Rahul    40
# Shobit   50

# %%
df.shape  # Give No of rows and columns
# Out:
# (100, 12)

# %%
df.columns
# Out:
# Index(['Index', 'Customer_Id', 'First_Name', 'Last_Name', 'Company', 'City',
#        'Country', 'Phone_1', 'Phone_2', 'Email', 'Subscription_Date',
#        'Website'],
#       dtype='object')

# %%
df.head(4)  # Gives 1st 4 rows
# Out:
#    Index      Customer_Id First_Name Last_Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
#
#                            Company               City              Country  \
# 0                  Rasmussen Group       East Leonard                Chile
# 1                      Vega-Gentry  East Jimmychester             Djibouti
# 2                    Murillo-Perry      Isabelborough  Antigua and Barbuda
# 3  Dominguez, Mcmillan and Donovan         Bensonview   Dominican Republic
#
#                   Phone_1              Phone_2                        Email  \
# 0            229.077.5154     397.884.0519x718     zunigavanessa@smith.info
# 1              5153435776     686-620-1820x944              vmata@colon.com
# 2         +1-539-402-0259  (496)978-3969x58947          beckycarr@hogan.com
# ...

# %%
df.sample(3)   # Gives any 3 random row as sample
# Out:
#     Index      Customer_Id First_Name Last_Name       Company         City  \
# 69     70  CC68FD1D3Bbbf22      Riley      Good      Wade PLC   Erikaville
# 39     40  17aD8e2dB3df03D     Sherry     Garza  Anderson Ltd    West John
# 25     26  09D7D7C8Fe09aea     Marcus     Moody     Giles Ltd  Kaitlyntown
#
#    Country               Phone_1             Phone_2  \
# 69  Canada            6977745822        855-436-7641
# 39  Poland  001-067-713-6440x158  (978)289-8785x5766
# 25  Panama          674-677-8623    909-277-5485x566
#
#                               Email Subscription_Date                 Website
# 69              alex06@galloway.com        2020-02-03      http://conway.org/
# 39                 ann48@miller.com        2021-11-01      http://spence.com/
# 25  donnamullins@norris-barrett.org        2022-05-24  https://www.curry.com/

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer_Id        100 non-null    object
#  2   First_Name         100 non-null    object
#  3   Last_Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone_1            100 non-null    object
#  8   Phone_2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription_Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %%
list[df['First_Name']]  # Converts First_Name into a list
# Out:
# list[0       Sheryl
# 1      Preston
# 2          Roy
# 3        Linda
# 4       Joanna
#         ...
# 95        Karl
# 96        Lynn
# 97        Fred
# 98      Yvonne
# 99    Clarence
# Name: First_Name, Length: 100, dtype: object]

# %% [markdown]
# ### Convert Series to DataFrame

# %%
b = pd.Series([1,2,3], index = [10, "Aashish", 4])
b
# Out:
# 10         1
# Aashish    2
# 4          3
# dtype: int64

# %%
d = pd.DataFrame(b)
d
# Out:
#          0
# 10       1
# Aashish  2
# 4        3

# %%
d['new column'] = 'Ram'
d
# Out:
#          0 new column
# 10       1        Ram
# Aashish  2        Ram
# 4        3        Ram

# %%
d['new column']
# Out:
# 10         Ram
# Aashish    Ram
# 4          Ram
# Name: new column, dtype: object

# %%
d
# Out:
#          0 new column
# 10       1        Ram
# Aashish  2        Ram
# 4        3        Ram

# %%
d.columns = ['id', "Name"]
d
# Out:
#          id Name
# 10        1  Ram
# Aashish   2  Ram
# 4         3  Ram

# %%
d.reset_index(drop = True)
# Out:
#    id Name
# 0   1  Ram
# 1   2  Ram
# 2   3  Ram

# %%
df = pd.read_csv('customers-100.csv')
df
# Out:
#     Index      Customer_Id First_Name Last_Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df_subset = df[['First_Name', 'Last_Name', 'Company', 'City', 'Country']]  # Creates a new dataframe from a Existing DataFrame
df_subset
# Out:
#    First_Name Last_Name                          Company               City  \
# 0      Sheryl    Baxter                  Rasmussen Group       East Leonard
# 1     Preston    Lozano                      Vega-Gentry  East Jimmychester
# 2         Roy     Berry                    Murillo-Perry      Isabelborough
# 3       Linda     Olsen  Dominguez, Mcmillan and Donovan         Bensonview
# 4      Joanna    Bender         Martin, Lang and Andrade     West Priscilla
# ..        ...       ...                              ...                ...
# 95       Karl     Greer                        Carey LLC       East Richard
# 96       Lynn  Atkinson            Ware, Burns and Oneal       New Bradview
# 97       Fred    Guerra                    Schmitt-Jones         Ortegaland
# 98     Yvonne    Farmer               Fitzgerald-Harrell    Lake Elijahview
# 99   Clarence    Haynes               Le, Nash and Cross          Judymouth
#
#                        Country
# ...

# %%
df1 = pd.read_excel('LUSID Excel.xlsx')
df1
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/tokern/piicatcher/master/tests/samples/sample-data.csv')
df2
# Out:
#              id gender   birthdate maiden_name      lname        fname  \
# 0   172-32-1176      m  1958/04/21       Smith      White      Johnson
# 1   514-14-8905      f  1944/12/22      Amaker     Borden       Ashley
# 2   213-46-8915      f  1958/04/21      Pinson      Green     Marjorie
# 3   524-02-7657      m  1962/03/25        Hall     Munsch       Jerome
# 4   489-36-8350      m  1964/09/06      Porter     Aragon       Robert
# 5   514-30-2668      f  1986/05/27   Nicholson    Russell        Jacki
# 6   505-88-5714      f  1963/09/23     Mcclain     Venson      Lillian
# 7   690-05-5315      m  1969/10/02       Kings     Conley       Thomas
# 8   646-44-9061      M  1978/01/12       Kurtz    Jackson      Charles
# 9   421-37-1396      f  1980/04/09      Linden      Davis        Susan
# 10  461-97-5660      f  1975/01/04     Kingdon     Watson         Gail
# 11  660-03-8360      f  1953/07/11     Onwunli   Garrison         Lisa
# ...

# %%
url_df = pd.read_html("https://catalog.data.gov/dataset/html-files")
url_df
# Out:
# [                     0                                                  1
#  0                @type                                       dcat:Dataset
#  1          accessLevel                                             public
#  2   accrualPeriodicity                                          irregular
#  3           bureauCode                                      [  "026:00" ]
#  4         contactPoint  {  "fn": "CAROL WIESEMAN",  "@type": "vcard:Co...
#  5          description  This is a resource where HTML files will be st...
#  6         distribution  [  {  "@type": "dcat:Distribution",  "title": ...
#  7           identifier                                       DASHLINK_332
#  8               issued                                         2011-04-01
#  9              keyword                  [  "ames",  "dashlink",  "nasa" ]
#  10         landingPage        https://c3.nasa.gov/dashlink/resources/332/
# ...

# %%
df3 = url_df[0]  # 0th index par dataframe hai
df3
# Out:
#                      0                                                  1
# 0                @type                                       dcat:Dataset
# 1          accessLevel                                             public
# 2   accrualPeriodicity                                          irregular
# 3           bureauCode                                      [  "026:00" ]
# 4         contactPoint  {  "fn": "CAROL WIESEMAN",  "@type": "vcard:Co...
# 5          description  This is a resource where HTML files will be st...
# 6         distribution  [  {  "@type": "dcat:Distribution",  "title": ...
# 7           identifier                                       DASHLINK_332
# 8               issued                                         2011-04-01
# 9              keyword                  [  "ames",  "dashlink",  "nasa" ]
# 10         landingPage        https://c3.nasa.gov/dashlink/resources/332/
# 11            modified                                         2025-04-01
# ...

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3.to_csv("Info.csv", index = False)
df3
# Out:
#                      0                                                  1
# 0                @type                                       dcat:Dataset
# 1          accessLevel                                             public
# 2   accrualPeriodicity                                          irregular
# 3           bureauCode                                      [  "026:00" ]
# 4         contactPoint  {  "fn": "CAROL WIESEMAN",  "@type": "vcard:Co...
# 5          description  This is a resource where HTML files will be st...
# 6         distribution  [  {  "@type": "dcat:Distribution",  "title": ...
# 7           identifier                                       DASHLINK_332
# 8               issued                                         2011-04-01
# 9              keyword                  [  "ames",  "dashlink",  "nasa" ]
# 10         landingPage        https://c3.nasa.gov/dashlink/resources/332/
# 11            modified                                         2025-04-01
# ...

# %%
url = "https://raw.githubusercontent.com/sharmadhiraj/free-json-datasets/refs/heads/master/datasets/nobel-prize-winners-by-year.json"
pd.read_json(url)
# Out:
#      year                                            winners
# 0    1901  [{'category': 'chemistry', 'winners': [{'name'...
# 1    1902  [{'category': 'chemistry', 'winners': [{'name'...
# 2    1903  [{'category': 'chemistry', 'winners': [{'name'...
# 3    1904  [{'category': 'chemistry', 'winners': [{'name'...
# 4    1905  [{'category': 'chemistry', 'winners': [{'name'...
# ..    ...                                                ...
# 110  2015  [{'category': 'chemistry', 'winners': [{'name'...
# 111  2016  [{'category': 'chemistry', 'winners': [{'name'...
# 112  2017  [{'category': 'chemistry', 'winners': [{'name'...
# 113  2018  [{'category': 'chemistry', 'winners': [{'name'...
# 114  2019  [{'category': 'chemistry', 'winners': [{'name'...
#
# [115 rows x 2 columns]

# %%
import requests
requests.get(url)
# Out:
# <Response [200]>
