# %%
# Solving the dataset
import pandas as pd

df = pd.read_csv('titanic dataset.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.describe()   # Gives statistical information about numerical column . Also known as 5 point summary
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.dtypes == 'object'   # Gives all object data types
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object'].index  # Gets us the names of columns whose datatype is object
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]  # Gives us whole df whose dataype is object
# Out:
#                                              Name     Sex              Ticket  \
# 0                                Kelly, Mr. James    male              330911
# 1                Wilkes, Mrs. James (Ellen Needs)  female              363272
# 2                       Myles, Mr. Thomas Francis    male              240276
# 3                                Wirz, Mr. Albert    male              315154
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female             3101298
# ..                                            ...     ...                 ...
# 413                            Spector, Mr. Woolf    male           A.5. 3236
# 414                  Oliva y Ocana, Dona. Fermina  female            PC 17758
# 415                  Saether, Mr. Simon Sivertsen    male  SOTON/O.Q. 3101262
# 416                           Ware, Mr. Frederick    male              359309
# 417                      Peter, Master. Michael J    male                2668
#
#     Cabin Embarked
# ...

# %%
df.describe(include = 'object')    # Gives summary stats of only object data type columns
# Out:
#                             Name   Sex    Ticket            Cabin Embarked
# count                        418   418       418               91      418
# unique                       418     2       363               76        3
# top     Peter, Master. Michael J  male  PC 17608  B57 B59 B63 B66        S
# freq                           1   266         5                3      270

# %%
df.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                      Name   Sex  \
# count    418.000000  418.000000  418.000000                       418   418
# unique          NaN         NaN         NaN                       418     2
# top             NaN         NaN         NaN  Peter, Master. Michael J  male
# freq            NaN         NaN         NaN                         1   266
# mean    1100.500000    0.363636    2.265550                       NaN   NaN
# std      120.810458    0.481622    0.841838                       NaN   NaN
# min      892.000000    0.000000    1.000000                       NaN   NaN
# 25%      996.250000    0.000000    1.000000                       NaN   NaN
# 50%     1100.500000    0.000000    3.000000                       NaN   NaN
# 75%     1204.750000    1.000000    3.000000                       NaN   NaN
# max     1309.000000    1.000000    3.000000                       NaN   NaN
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df[1:12]
# Out:
#     PassengerId  Survived  Pclass  \
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 1               Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                      Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                               Wirz, Mr. Albert    male  27.0      0      0
# 4   Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                     Svensson, Mr. Johan Cervin    male  14.0      0      0
# 6                           Connolly, Miss. Kate  female  30.0      0      0
# ...

# %%
df['new_row'] = "python"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
del df['new_row']
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
pd.Categorical(df['Cabin'])  # Different categories of Cabin
# Out:
# [NaN, NaN, NaN, NaN, NaN, ..., NaN, 'C105', NaN, NaN, NaN]
# Length: 418
# Categories (76, object): ['A11', 'A18', 'A21', 'A29', ..., 'F2', 'F33', 'F4', 'G6']

# %%
df['Cabin'].unique()   # Gives unique values of Cabin
# Out:
# array([nan, 'B45', 'E31', 'B57 B59 B63 B66', 'B36', 'A21', 'C78', 'D34',
#        'D19', 'A9', 'D15', 'C31', 'C23 C25 C27', 'F G63', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C101', 'C55 C57', 'B71', 'C46', 'C116',
#        'F', 'A29', 'G6', 'C6', 'C28', 'C51', 'E46', 'C54', 'C97', 'D22',
#        'B10', 'F4', 'E45', 'E52', 'D30', 'B58 B60', 'E34', 'C62 C64',
#        'A11', 'B11', 'C80', 'F33', 'C85', 'D37', 'C86', 'D21', 'C89',
#        'F E46', 'A34', 'D', 'B26', 'C22 C26', 'B69', 'C32', 'B78',
#        'F E57', 'F2', 'A18', 'C106', 'B51 B53 B55', 'D10 D12', 'E60',
#        'E50', 'E39 E41', 'B52 B54 B56', 'C39', 'B24', 'D28', 'B41', 'C7',
#        'D40', 'D38', 'C105'], dtype=object)

# %%
df['Cabin'].nunique()  # Gives number of unique values in column Cabin
# Out:
# 76

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Check how many passengers are children under 5 years old?
df[df['Age'] < 5]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 89           981         0       2              Wells, Master. Ralph Lester
# 117         1009         1       3          Sandstrom, Miss. Beatrice Irene
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 250         1142         1       2                    West, Miss. Barbara J
# 263         1155         1       3             Klasen, Miss. Gertrud Emilia
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 284         1176         1       3              Rosblom, Miss. Salli Helena
# 296         1188         1       2                    Laroche, Miss. Louise
# 307         1199         0       3                Aks, Master. Philip Frank
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 409         1301         1       3                Peacock, Miss. Treasteall
#
# ...

# %%
len(df[df['Age'] < 5])   # Gets us the number of passengers under 5 years
# Out:
# 11

# %%
# How many passengers are less than 18 years old?
df[df['Age'] < 18]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 5            897         0       3                 Svensson, Mr. Johan Cervin
# 21           913         0       3                  Olsen, Master. Artur Karl
# 55           947         0       3                       Rice, Master. Albert
# 60           952         0       3                            Dika, Mr. Mirko
# 64           956         0       1                Ryerson, Master. John Borie
# 80           972         0       3                       Boulos, Master. Akar
# 89           981         0       2                Wells, Master. Ralph Lester
# 104          996         1       3  Thomas, Mrs. Alexander (Thamine Thelma")"
# 117         1009         1       3            Sandstrom, Miss. Beatrice Irene
# 120         1012         1       2                       Watt, Miss. Bertha J
# 125         1017         1       3                   Cribb, Miss. Laura Alice
# ...

# %%
len(df[df['Age'] < 18])
# Out:
# 41

# %%
df['Fare']  # Gets us the average fare of tickets
# Out:
# 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
#          ...
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 418, dtype: float64

# %%
df['Fare'].mean()
# Out:
# np.float64(35.627188489208635)

# %%
# Q. Find Cabin with maximum Fare.
df.loc[df['Fare'].idxmax(), 'Cabin']
# Out:
# 'B51 B53 B55'

# %%
# Q. How many passengers have paid less than avg fare
len(df[df['Fare'] < df['Fare'].mean()])
# Out:
# 320

# %%
# Q. How many Passengers paid 0 fare?
len(df[df['Fare'] == 0])
# Out:
# 2

# %%
df['Sex'].value_counts(normalize = True)  # Normalize = True Gets us percentage of Male and Female
# Out:
# Sex
# male      0.636364
# female    0.363636
# Name: proportion, dtype: float64

# %%
# How many Passengers Survived
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Survived'].value_counts(normalize = True)
# Out:
# Survived
# 0    0.636364
# 1    0.363636
# Name: proportion, dtype: float64

# %%
df[df['Fare'] == max(df.Fare)]
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 343      1  PC 17755  512.3292  B51 B53 B55        C
