# %%
import numpy as np

# %%
arr1 = np.random.randint(1,3, (3,3))
arr2 = np.random.randint(1,3, (3,3))

# %%
arr1
# Out:
# array([[1, 2, 2],
#        [1, 2, 2],
#        [1, 2, 2]], dtype=int32)

# %%
arr2
# Out:
# array([[1, 2, 1],
#        [2, 2, 1],
#        [1, 1, 1]], dtype=int32)

# %%
arr1.flatten()  # Return a copy of the array collapsed into one dimension original arr1 remains same
# Out:
# array([1, 2, 2, 1, 2, 2, 1, 2, 2], dtype=int32)

# %%
# Expand Dimesion
arr = np.array([1,2,3,4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
arr.ndim
# Out:
# 1

# %%
np.expand_dims(arr, axis = 0)   # Expand dimesion by one along axis 0(Row wise )
# Out:
# array([[1, 2, 3, 4]])

# %%
np.expand_dims(arr, axis = 1)   # Expand dimesion by one along axis 1(column wise)
# Out:
# array([[1],
#        [2],
#        [3],
#        [4]])

# %%
np.squeeze(arr)  # Decrease Dimension by 1
# Out:
# array([1, 2, 3, 4])

# %%
np.repeat(arr, 3)   # Repeats the array
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4])

# %%
arr1
# Out:
# array([[1, 2, 2],
#        [1, 2, 2],
#        [1, 2, 2]], dtype=int32)

# %%
np.repeat(arr1, 2, axis = 1)
# Out:
# array([[1, 1, 2, 2, 2, 2],
#        [1, 1, 2, 2, 2, 2],
#        [1, 1, 2, 2, 2, 2]], dtype=int32)

# %%
np.roll(arr1, -2, axis = 1)  # Rotates the array
# Out:
# array([[2, 1, 2],
#        [2, 1, 2],
#        [2, 1, 2]], dtype=int32)

# %%
# Operations on numpy string array

a = np.array(["aashish", "singh"])

# %%
a
# Out:
# array(['aashish', 'singh'], dtype='<U7')

# %%
np.char.capitalize(a)
# Out:
# array(['Aashish', 'Singh'], dtype='<U7')

# %% [markdown]
# ### Mathematical Functions

# %%
arr2
# Out:
# array([[1, 2, 1],
#        [2, 2, 1],
#        [1, 1, 1]], dtype=int32)

# %%
np.sin(arr2)
# Out:
# array([[0.84147098, 0.90929743, 0.84147098],
#        [0.90929743, 0.90929743, 0.84147098],
#        [0.84147098, 0.84147098, 0.84147098]])

# %%
np.cos(arr2)
# Out:
# array([[ 0.54030231, -0.41614684,  0.54030231],
#        [-0.41614684, -0.41614684,  0.54030231],
#        [ 0.54030231,  0.54030231,  0.54030231]])

# %%
np.mod(arr1,arr2)
# Out:
# array([[0, 0, 0],
#        [1, 0, 0],
#        [0, 0, 0]], dtype=int32)

# %% [markdown]
# ### Sort Search

# %%
b = np.array([8,1,9,2,7])
b
# Out:
# array([8, 1, 9, 2, 7])

# %%
np.sort(b)
# Out:
# array([1, 2, 7, 8, 9])

# %%
c = np.array([6,4,1,2,9,8,6,2])
np.sort(c)
# Out:
# array([1, 2, 2, 4, 6, 6, 8, 9])

# %%
np.searchsorted(c, 5)  # Finds Indices where elements should be inserted to maintain order.
# Out:
# np.int64(4)

# %%
d = np.array([0,5,3,1,1,3,4,0,4,0,0,8])
np.count_nonzero(d)
# Out:
# 8

# %%
d.byteswap()   # Gives byte representation of all elements in d
# Out:
# array([                 0, 360287970189639680, 216172782113783808,
#         72057594037927936,  72057594037927936, 216172782113783808,
#        288230376151711744,                  0, 288230376151711744,
#                         0,                  0, 576460752303423488])

# %%
arr1
# Out:
# array([[1, 2, 2],
#        [1, 2, 2],
#        [1, 2, 2]], dtype=int32)

# %%
arr2
# Out:
# array([[1, 2, 1],
#        [2, 2, 1],
#        [1, 1, 1]], dtype=int32)

# %%
np.linalg.det(arr2)  # Gets us the determinant of any matrix
# Out:
# np.float64(-1.0)

# %%
np.linalg.inv(arr2)
# Out:
# array([[-1.,  1.,  0.],
#        [ 1.,  0., -1.],
#        [ 0., -1.,  2.]])
