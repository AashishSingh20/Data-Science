# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://aashish_db_user:<password>@initialuse.tozau3c.mongodb.net/?appName=InitialUse")

# %%
client
# Out:
# MongoClient(host=['ac-c7yu65j-shard-00-02.tozau3c.mongodb.net:27017', 'ac-c7yu65j-shard-00-00.tozau3c.mongodb.net:27017', 'ac-c7yu65j-shard-00-01.tozau3c.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='InitialUse', authsource='admin', replicaset='atlas-zs09y3-shard-0', tls=True)

# %%
db = client["first_db"]   # Here I have created a database named first_db

# %%
coll_create = db["my_record"]  # Here Collection is created >> collection in unstruc db = tables in struc db

# %%
data = {"name": "Aashish",
        "class": "ML",
        "Timing":"Flexible"}

# %%
coll_create.insert_one(data)
# Out:
# InsertOneResult(ObjectId('6a380f067f0d042d09e835e7'), acknowledged=True)

# %%
data2 = {"courses": ["Data Science", "Machine Learning", "Python", "Operating System"],
         "Instructor": ["Rohit", "Kamal", "Rajeev", "Ankit"],
        }

# %%
coll_create.insert_one(data2)
# Out:
# InsertOneResult(ObjectId('6a3815a57f0d042d09e835e8'), acknowledged=True)

# %%
data3 = [
  { "name": "Amy", "address": "Apple st 652" },
  { "name": "Hannah", "address": "Mountain 21" },
  { "name": "Michael", "address": "Valley 345" },
  { "name": "Sandy", "address": "Ocean blvd 2" },
  { "name": "Betty", "address": "Green Grass 1" },
  { "name": "Richard", "address": "Sky st 331" },
  { "name": "Susan", "address": "One way 98" },
  { "name": "Vicky", "address": "Yellow Garden 2" },
  { "name": "Ben", "address": "Park Lane 38" },
  { "name": "William", "address": "Central st 954" },
  { "name": "Chuck", "address": "Main Road 989" },
  { "name": "Viola", "address": "Sideway 1633" }
]

# %%
coll_create.insert_many(data3)
# Out:
# InsertManyResult([ObjectId('6a38182c7f0d042d09e835e9'), ObjectId('6a38182c7f0d042d09e835ea'), ObjectId('6a38182c7f0d042d09e835eb'), ObjectId('6a38182c7f0d042d09e835ec'), ObjectId('6a38182c7f0d042d09e835ed'), ObjectId('6a38182c7f0d042d09e835ee'), ObjectId('6a38182c7f0d042d09e835ef'), ObjectId('6a38182c7f0d042d09e835f0'), ObjectId('6a38182c7f0d042d09e835f1'), ObjectId('6a38182c7f0d042d09e835f2'), ObjectId('6a38182c7f0d042d09e835f3'), ObjectId('6a38182c7f0d042d09e835f4')], acknowledged=True)

# %%
list_of_records = [
    {'companyName': 'pw skills',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'pw skills',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'pw skills',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program'}
]

# %%
coll_create.insert_many(list_of_records)
# Out:
# InsertManyResult([ObjectId('6a3819e47f0d042d09e835f5'), ObjectId('6a3819e47f0d042d09e835f6'), ObjectId('6a3819e47f0d042d09e835f7')], acknowledged=True)

# %%
for i in coll_create.find():  # Gets us all the records in the db
    print(i)
# Out:
# {'_id': ObjectId('6a380f067f0d042d09e835e7'), 'name': 'Aashish', 'class': 'ML', 'Timing': 'Flexible'}
# {'_id': ObjectId('6a3815a57f0d042d09e835e8'), 'courses': ['Data Science', 'Machine Learning', 'Python', 'Operating System'], 'Instructor': ['Rohit', 'Kamal', 'Rajeev', 'Ankit']}
# {'_id': ObjectId('6a38182c7f0d042d09e835e9'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ea'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('6a38182c7f0d042d09e835eb'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ec'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ed'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ee'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ef'), 'name': 'Susan', 'address': 'One way 98'}
# ...

# %%
random_data = [
    {'_id': '3', 'companyName': 'pw skills', 'Faculty': 'XYZ'},
    {'_id': '4', 'companyName': 'pw skills', 'Faculty': 'ABC'},
    {'_id': '5', 'companyName': 'pw skills', 'Faculty': 'PQR'},
]

# %%
coll_create.insert_many(random_data)
# Out:
# InsertManyResult(['3', '4', '5'], acknowledged=True)

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('6a380f067f0d042d09e835e7'), 'name': 'Aashish', 'class': 'ML', 'Timing': 'Flexible'}
# {'_id': ObjectId('6a3815a57f0d042d09e835e8'), 'courses': ['Data Science', 'Machine Learning', 'Python', 'Operating System'], 'Instructor': ['Rohit', 'Kamal', 'Rajeev', 'Ankit']}
# {'_id': ObjectId('6a38182c7f0d042d09e835e9'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ea'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('6a38182c7f0d042d09e835eb'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ec'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ed'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ee'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ef'), 'name': 'Susan', 'address': 'One way 98'}
# ...

# %%
coll_create.find_one()  # Just gives us one record
# Out:
# {'_id': ObjectId('6a380f067f0d042d09e835e7'),
#  'name': 'Aashish',
#  'class': 'ML',
#  'Timing': 'Flexible'}

# %%
for i in coll_create.find({'companyName': 'pw skills'}):
    print(i)
# Out:
# {'_id': ObjectId('6a3819e47f0d042d09e835f5'), 'companyName': 'pw skills', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('6a3819e47f0d042d09e835f6'), 'companyName': 'pw skills', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('6a3819e47f0d042d09e835f7'), 'companyName': 'pw skills', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': '3', 'companyName': 'pw skills', 'Faculty': 'XYZ'}
# {'_id': '4', 'companyName': 'pw skills', 'Faculty': 'ABC'}
# {'_id': '5', 'companyName': 'pw skills', 'Faculty': 'PQR'}

# %%
for i in coll_create.find({'_id': {'$gte':'3'}}):  # Fetch all records whose id is >= 3
    print(i)
# Out:
# {'_id': '3', 'companyName': 'pw skills', 'Faculty': 'XYZ'}
# {'_id': '4', 'companyName': 'pw skills', 'Faculty': 'ABC'}
# {'_id': '5', 'companyName': 'pw skills', 'Faculty': 'PQR'}

# %%
coll_create.update_many({'companyName':'pw skills'}, {'$set': {'companyName':'College'}})
# Out:
# UpdateResult({'n': 6, 'electionId': ObjectId('7fffffff0000000000000402'), 'opTime': {'ts': Timestamp(1782062282, 6), 't': 1026}, 'nModified': 6, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1782062282, 6), 'signature': {'hash': b'\x9b\xa2\xe3o)B\xaa\xcb\x05f\xf9\x11+9I55\xe2Y\x8b', 'keyId': 7623796855704387585}}, 'operationTime': Timestamp(1782062282, 6), 'updatedExisting': True}, acknowledged=True)

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('6a380f067f0d042d09e835e7'), 'name': 'Aashish', 'class': 'ML', 'Timing': 'Flexible'}
# {'_id': ObjectId('6a3815a57f0d042d09e835e8'), 'courses': ['Data Science', 'Machine Learning', 'Python', 'Operating System'], 'Instructor': ['Rohit', 'Kamal', 'Rajeev', 'Ankit']}
# {'_id': ObjectId('6a38182c7f0d042d09e835e9'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ea'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('6a38182c7f0d042d09e835eb'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ec'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ed'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ee'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('6a38182c7f0d042d09e835ef'), 'name': 'Susan', 'address': 'One way 98'}
# ...

# %%
coll_create.drop()  # Drops all records
